# %% [markdown]
# <a href="https://colab.research.google.com/github/Catatau52/Data_Mining-Captura_Vp_Dy_FII/blob/main/Coleta_Vp%26Dy_FIIs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Instalando Bibliotecas

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (3.2)

# %%
import pandas as pd
import numpy as np
import decimal
import os
import zipfile
from zipfile import ZipFile
import wget
import requests
import xml.etree.ElementTree as ET

# %% [markdown]
# #Capturando dados Relevantes

# %% [markdown]
# Fonte:https://dados.cvm.gov.br/dados/FII/DOC/INF_MENSAL/DADOS/

# %%
wget.download('https://dados.cvm.gov.br/dados/FII/DOC/INF_MENSAL/DADOS/inf_mensal_fii_2023.zip')
# Out:
# 'inf_mensal_fii_2023 (1).zip'

# %%
ZipFile('/content/inf_mensal_fii_2023.zip', 'r').extractall('Dados')

# %%
df1= pd.read_csv('/content/Dados/inf_mensal_fii_geral_2023.csv', sep=';', decimal=',', encoding='ISO-8859-1')
df2 = pd.read_csv('/content/Dados/inf_mensal_fii_complemento_2023.csv', sep=';', decimal=',', encoding='ISO-8859-1')

# %%
df1 = df1[['CNPJ_Fundo','Data_Referencia','Nome_Fundo']]
df2 = df2[['CNPJ_Fundo','Data_Referencia','Valor_Patrimonial_Cotas','Percentual_Dividend_Yield_Mes']]

# %%
df1.head(12)
# Out:
#             CNPJ_Fundo Data_Referencia  \
# 0   00.332.266/0001-31      2023-01-01
# 1   00.332.266/0001-31      2023-02-01
# 2   00.332.266/0001-31      2023-03-01
# 3   00.332.266/0001-31      2023-04-01
# 4   00.332.266/0001-31      2023-05-01
# 5   00.332.266/0001-31      2023-06-01
# 6   00.613.094/0001-74      2023-01-01
# 7   00.613.094/0001-74      2023-02-01
# 8   00.613.094/0001-74      2023-03-01
# 9   00.613.094/0001-74      2023-04-01
# 10  00.613.094/0001-74      2023-05-01
# 11  00.613.094/0001-74      2023-06-01
#
#                                            Nome_Fundo
# 0   FUNDO DE INVESTIMENTO IMOBILIÁRIO VIA PARQUE S...
# 1   FUNDO DE INVESTIMENTO IMOBILIÁRIO VIA PARQUE S...
# 2   FUNDO DE INVESTIMENTO IMOBILIÁRIO VIA PARQUE S...
# 3   FUNDO DE INVESTIMENTO IMOBILIÁRIO VIA PARQUE S...
# 4   FUNDO DE INVESTIMENTO IMOBILIÁRIO VIA PARQUE S...
# 5   FUNDO DE INVESTIMENTO IMOBILIÁRIO VIA PARQUE S...
# 6           FUNDO DE INVESTIMENTO IMOBILIÁRIO PANAMBY
# 7           FUNDO DE INVESTIMENTO IMOBILIÁRIO PANAMBY
# 8                                         FII PANAMBY
# 9                                         FII PANAMBY
# 10                                        FII PANAMBY
# 11                                        FII PANAMBY

# %%
df2.head(12)
# Out:
#             CNPJ_Fundo Data_Referencia Valor_Patrimonial_Cotas  \
# 0   00.332.266/0001-31      2023-01-01        191.463186776847
# 1   00.332.266/0001-31      2023-02-01        191.566149947735
# 2   00.332.266/0001-31      2023-03-01        192.016269837784
# 3   00.332.266/0001-31      2023-04-01        191.988287873252
# 4   00.332.266/0001-31      2023-05-01        191.544270679882
# 5   00.332.266/0001-31      2023-06-01         192.68904566507
# 6   00.613.094/0001-74      2023-01-01       -16.0559810126582
# 7   00.613.094/0001-74      2023-02-01       -16.5307877241561
# 8   00.613.094/0001-74      2023-03-01       -17.0094347969409
# 9   00.613.094/0001-74      2023-04-01       -17.4642570543249
# 10  00.613.094/0001-74      2023-05-01       -18.0787609704641
# 11  00.613.094/0001-74      2023-06-01       -18.6881504483122
#
#    Percentual_Dividend_Yield_Mes
# 0                       0.006449
# 1                       0.003238
# 2                       0.004281
# 3                       0.005208
# 4                       0.003542
# 5                       0.008878
# 6                              0
# 7                              0
# 8                              0
# 9                              0
# 10                             0
# 11                             0

# %% [markdown]
# #Filtrando e mesclando bases dos resultados do último mês

# %% [markdown]
# Filtrando pelo último resultado

# %%
df1 = df1.loc[df1['Data_Referencia'] == '2023-06-01']
df2 = df2.loc[df2['Data_Referencia'] == '2023-06-01']
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)

# %% [markdown]
# Filtrando pelos tickers do FIIs. Para isso, necessito dos tickers dos FII que não encontrei ou são fornecidos pela CVM.

# %% [markdown]
# Fonte: https://www.infomoney.com.br/planilhas/cnpj-das-empresas-listadas-na-b3-para-declarar-acoes-no-imposto-de-renda/

# %%
FII = pd.read_csv('/content/lista_de_fiis.csv',sep=';',  encoding='ISO-8859-1',index_col=False)

# %%
FII.head(10)
# Out:
#                                           Nome_Fundo   Código  \
# 0  FUNDO DE INVESTIMENTO IMOBILIÁRIO GRAND PLAZA ...   ABCP11
# 1  AF INVEST CRI FUNDO DE INVESTIMENTO IMOBILIÁRI...   AFHI11
# 2  AUTONOMY EDIFÍCIOS CORPORATIVOS FUNDO DE INVES...   AIEC11
# 3  FUNDO DE INVESTIMENTO IMOBILIÁRIO FII TORRE AL...   ALMI11
# 4  ALIANZA MULTIESTRATÉGIA FUNDO DE INVESTIMENTO ...   ALZM11
# 5  ALIANZA TRUST RENDA IMOBILIÁRIA FUNDO DE INVES...   ALZR11
# 6         FUNDO DE INVESTIMENTO IMOBILIÁRIO ANCAR IC  ANCR11B
# 7  NAVI RESIDENCIAL FUNDO DE INVESTIMENTO IMOBILI...   APTO11
# 8       FUNDO DE INVESTIMENTO IMOBILIÁRIO APEX MALLS   APXM11
# 9  AROEIRA 333 RENDA LOGÍSTICA FUNDO DE INVESTIME...   AROA11
#
#                  CNPJ
# 0  01.201.140/0001-90
# 1  36.642.293/0001-58
# 2  35.765.826/0001-26
# 3  07.122.725/0001-00
# 4  34.847.063/0001-08
# 5  28.737.771/0001-85
# 6  07.789.135/0001-27
# 7  42.432.327/0001-82
# 8  43.010.485/0001-07
# 9  44.674.528/0001-11

# %%
FII = FII.rename(columns={'CNPJ': 'CNPJ_Fundo'})
FII = FII[['Nome_Fundo', 'CNPJ_Fundo', 'Código']]

# %%
df_merged = pd.merge(FII, df1, on='CNPJ_Fundo',how='outer')
df_merged = pd.merge(df_merged, df2, on='CNPJ_Fundo',how='outer')
df_merged = df_merged.dropna()

# %%
# Adicionar o sufixo '.SA' à coluna 'Código'
df_merged['Código'] = df_merged['Código'].apply(lambda x: x + '.SA')

# %%
df_merged = df_merged.drop(['Nome_Fundo_y','Data_Referencia_y'], axis =1 )
df_merged = df_merged.rename(columns={'Nome_Fundo_x': 'Nome_Fundo', 'Data_Referencia_x':'Data_Referencia'})

# %%
df_merged.head(10)
# Out:
#                                           Nome_Fundo          CNPJ_Fundo  \
# 0  FUNDO DE INVESTIMENTO IMOBILIÁRIO GRAND PLAZA ...  01.201.140/0001-90
# 1  AF INVEST CRI FUNDO DE INVESTIMENTO IMOBILIÁRI...  36.642.293/0001-58
# 2  AUTONOMY EDIFÍCIOS CORPORATIVOS FUNDO DE INVES...  35.765.826/0001-26
# 3  FUNDO DE INVESTIMENTO IMOBILIÁRIO FII TORRE AL...  07.122.725/0001-00
# 4  ALIANZA MULTIESTRATÉGIA FUNDO DE INVESTIMENTO ...  34.847.063/0001-08
# 5  ALIANZA TRUST RENDA IMOBILIÁRIA FUNDO DE INVES...  28.737.771/0001-85
# 6         FUNDO DE INVESTIMENTO IMOBILIÁRIO ANCAR IC  07.789.135/0001-27
# 7  NAVI RESIDENCIAL FUNDO DE INVESTIMENTO IMOBILI...  42.432.327/0001-82
# 8       FUNDO DE INVESTIMENTO IMOBILIÁRIO APEX MALLS  43.010.485/0001-07
# 9  AROEIRA 333 RENDA LOGÍSTICA FUNDO DE INVESTIME...  44.674.528/0001-11
#
#        Código Data_Referencia Valor_Patrimonial_Cotas  \
# 0   ABCP11.SA      2023-06-01        91.7721727929138
# 1   AFHI11.SA      2023-06-01               96.172392
# 2   AIEC11.SA      2023-06-01              94.6052923
# 3   ALMI11.SA      2023-06-01              2028.18728
# 4   ALZM11.SA      2023-06-01               92.460353
# 5   ALZR11.SA      2023-06-01              106.687945
# 6  ANCR11B.SA      2023-06-01        3574.17401828554
# 7   APTO11.SA      2023-06-01        10.5897642627186
# 8   APXM11.SA      2023-06-01               95.109811
# 9   AROA11.SA      2023-06-01              1.06707586
#
#   Percentual_Dividend_Yield_Mes
# 0                      0.005445
# 1                      0.011675
# 2                    0.00825022
# 3                      0.001033
# 4                      0.008615
# 5                      0.006467
# 6                    0.02266102
# 7                      0.011386
# 8                      0.007103
# 9                    0.00310261

# %% [markdown]
# #Filtrando os FII da minha carteira pessoal

# %%
carteira_fii = ['KISU11.SA','RINV11.SA','HGLG11.SA','BTLG11.SA','VISC11.SA','MALL11.SA','JSRE11.SA','HGRE11.SA',
                'HGRU11.SA','FIIB11.SA','MCCI11.SA','RRCI11.SA','IRDM11.SA','BDIF11.SA','VGIA11.SA']

# %%
df_filtrado = df_merged.loc[df_merged['Código'].isin(carteira_fii)]
df_filtrado = df_filtrado.reset_index(drop=True)
df_filtrado = df_filtrado[['Data_Referencia','Código','Valor_Patrimonial_Cotas','Percentual_Dividend_Yield_Mes']]

# %%
df_filtrado['Valor_Patrimonial_Cotas'] = pd.to_numeric(df_filtrado['Valor_Patrimonial_Cotas'])

# %%
df_filtrado
# Out:
#    Data_Referencia     Código  Valor_Patrimonial_Cotas  \
# 0       2023-06-01  BTLG11.SA                    98.22
# 1       2023-06-01  FIIB11.SA                   461.63
# 2       2023-06-01  HGLG11.SA                   153.84
# 3       2023-06-01  HGRE11.SA                   155.48
# 4       2023-06-01  HGRU11.SA                   123.51
# 5       2023-06-01  IRDM11.SA                    89.63
# 6       2023-06-01  JSRE11.SA                   112.73
# 7       2023-06-01  KISU11.SA                     9.20
# 8       2023-06-01  MALL11.SA                   119.99
# 9       2023-06-01  MCCI11.SA                    96.16
# 10      2023-06-01  RINV11.SA                   109.43
# 11      2023-06-01  RRCI11.SA                    93.12
# 12      2023-06-01  VISC11.SA                   115.26
#
#    Percentual_Dividend_Yield_Mes
# 0                       0.008909
# 1                       0.007046
# 2                       0.009803
# 3                       0.008957
# 4                       0.011299
# 5                       0.009687
# 6                       0.004081
# 7                       0.009343
# 8                       0.006667
# 9                       0.010671
# 10                      0.017705
# 11                      0.010828
# 12                       0.00707

# %%
df_filtrado.to_csv('fii.csv', index=False)
